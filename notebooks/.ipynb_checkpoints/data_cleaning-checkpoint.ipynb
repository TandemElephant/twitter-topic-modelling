# %% [markdown]
# # Clean that twitter data!
#
# Use of the "Table of Contents" nbextension is highly recommended.

# %% [markdown]
# ### Basic imports, settings

# %%
import numpy as np
import pandas as pd
import re
import nltk
import os
import json
import sys
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth',100)

# %% [markdown]
# ### Check variables in memory

# %%
import sys

# These are the usual ipython objects, including this one you are creating
ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

# Get a sorted list of the objects and their sizes
sorted([(x, sys.getsizeof(globals().get(x))) for x in dir() if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)
# Out:
# [('np', 80), ('pd', 80)]

# %% [markdown]
# ## Read data

# %%
dir_path = '../data/tweets_London_20km'
data = pd.DataFrame()

print('Loading tweets from', dir_path)
file_names = [file for file in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, file))]
for file_name in file_names:
    file_path = dir_path + '/' + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        tweets = pd.read_json(file)
        data = pd.concat([data, tweets], ignore_index=True)
        
print('Successfully loaded {} tweets from {} files.'.format(len(data), len(file_names)))
# Out:
# Loading tweets from ../data/tweets_London_20km
# Successfully loaded 100000 tweets from 100 files.

# %%
original_text = data.text
original_text
# Out:
# 0        Please support me by voting for me at MAXIM Covergirl 🙏🏼❤️ Link in my Bio or here:\nhttps://t.co...
# 1        👏👏 Rohit Sharma brings up fifty in his very first innings as a Test opener #INDvSA 👍👍 keep going...
# 2                                                        Someone take Freddy’s phone https://t.co/XYXR55dk8h
# 3        According to @AtholT admission, the DA benefited from Steinhoff corruption.\n\nThey not only rec...
# 4        Thank you for all the applications you sent through on the scholarship announcement. We are now ...
# 5        @coolstarorg This is how I imagine Coolstar looks when he cosplays as https://t.co/eYLQCihNKg.\n...
# 6                                               All I can say about life is, Oh God, enjoy it! (Bob Newhart)
# 7        @justwillhill @issameakaylee @case_burn @califuneral @txtuknee @_freedomperry_ recognition does ...
# 8                                                                                            @ZZTop Rock On!
# 9                  Whoever is reading this,we are now dating in fact I can't live without you. Good morning.
# 10                                            Haseul is a main vocalist so @loonatheworld treat her like one
# 11                                                               @TheYoung_King05 Ikyfl . You don’t do that?
# 12                                                 Without football, my life is worth nothing. -Cristiano R.
# 13       @crybabyscorp YEAH its easy to write a character goin batshit but its hard to give them More Dep...
# 14                                                               @i69monsters Physical or mental unwellness?
# 15                                                                                      @SuperMegaShow hank?
# 16       @tatynancy2 @squishyy_do @imjonginswife Baek is the leader bc he has the best qualities for it h...
# 17                                                                            Amen x https://t.co/K7iQwu8O4w
# 18                                                     @Nyaprincesa Wait what? Lol when did you plan this???
# 19       Movies: okay let's give this female character gorgeous hair, big titties, and some non-explicit ...
# 20            @mhmarklee I'm truly happy for you! \nps. @haechanisun pls do take a good care of this lil cub
# 21       Yuudoe: *voice echoes around* TTTHHHIIISSS IIISSS MMMYYY SSSPPPEEECCCIIIAALLL AAATTTTAAACCKKK, C...
# 22                                                                             sex with man better than like
# 23                                       mfs ain't stupid believe me. they won't lol https://t.co/wWWVaaf9tU
# 24       I regret forgetting to make those ramen noodles I planned to make tonight, I didn't eat much for...
# 25       Before I go, I made a call to the clinic and explain the receptionist about my problem. I clearl...
# 26                                                                 @ShelleyM1974 Big game tonight  hunnie xx
# 27                                                                                           @sam_wazi Oh oh
# 28       This week you got some money, last week you were almost homeless ? You still have some things to...
# 29                                                                             Full of love but I hate you 💔
#                                                         ...
# 99970                                                         @simran_dhunna Remember when we were teenagers
# 99971                                                                        easily. https://t.co/A9ooP3NLJy
# 99972                                                             @MostHatedOEG @youneedkaycee Biggz be like
# 99973    I’m so proud of where I’m at, mentally &amp; emotionally. It took a long time.. but I am thoroug...
# 99974    The Collarwali tigress from Pench was given this title as she was monitored through a radio coll...
# 99975                                Fuck- FUCK \n\nFuCkkkKk https://t.co/LQ9dyGUAmO https://t.co/fDYjVxvisX
# 99976    I literally had a friend the same who was 20+ and like damn man😩😂 they’re an ex friend now tho s...
# 99977    @assTV_ Where do you wannna be if not that? This is impressive... Congrats you are disciplined a...
# 99978                                                                 Mj's post become more aesthetic lately
# 99979                                  @Dis_Vibe That means so much. More than you might think, to be honest
# 99980                                                 @moshinnsimbi @the_travor_guy This video is edited tho
# 99981    @Schmarn7 @jeremynewberger Hillary made a ton of cash from Russia. Ukraine treated Drug boy Bide...
# 99982                                                         @GlennHowerton is creepier than Dennis Reynold
# 99983                                                 Is this when we were pink? Or? https://t.co/XzSgSu6ImG
# 99984                                      How I look when you wake me up from sleep https://t.co/Jd49wNLZJg
# 99985                                                 @sx6_magnusz I had to get my papo for the maledict bro
# 99986    @bigmessbby most public schools don't make you buy text books, but i go to a private school and ...
# 99987                                            nothing but 1/4 reps. not impressed https://t.co/azA0xP94JO
# 99988    I'm feeling real bad tonight.. If you feel like saying some nice things to me I would appreciate...
# 99989                                                         Great giveaway, thx :) https://t.co/63LnJKqv3H
# 99990                                                                    Mark Garcia https://t.co/4gpux52tu8
# 99991    @CaseyNewton @ewarren Loving the socially correct left  turning on each other with a viciousness...
# 99992                                         @curIies 2004???????? you make me sick https://t.co/eivorqeX7n
# 99993                                                                  "I'm ok I'm ok" says Lara \n\n#INDvSA
# 99994                                                  My guy! Appreciate you bro 🙏🏾 https://t.co/QQKxSb3vqC
# 99995                                   @AndrewYang I have less bots following me... https://t.co/jzo3AIaujk
# 99996                                                             @aretteepls I love her sm she the best 🥺🥺🥺
# 99997                                                                    No just noo https://t.co/mcl3Tu2Scv
# 99998                                               It’s past midnight so yeah I need sum titties to suck on
# 99999    i want an egg roll and some dumplings i’m so mad at any state that can’t provide me with basic n...
# Name: text, Length: 100000, dtype: object

# %% [markdown]
# ## Clean data

# %% [markdown]
# ### Lower case, strip

# %%
# everything in lower case, strip
data['text'] = data.text.str.lower()
data['text'] = data.text.str.strip()

# %% [markdown]
# ### Remove tags, usernames, hyperlinks

# %%
# remove every #tag 
data['text'] = data.text.str.replace(r'#\S*', '')

# %%
# remove every @username
data['text'] = data.text.str.replace(r'@\S*', '')

# %%
# remove links
data['text'] = data.text.str.replace(r'http(\S)*', '')

# %% [markdown]
# ### Remove punctuation

# %%
# side note: f*ck those wierdly encoded characters, I'm gonna deal with them in another way... :@
data['text'] = data.text.str.replace(r'[\.,;:?!\(\)\n\t]','')

# %% [markdown]
# ### Tokenize

# %%
from nltk.tokenize import TweetTokenizer

# strip_handles because I'm not sure what it does (maybe removes usernames?),
# reduce_len because I want 'waaaaaay' to be equal to 'waaay'
tokenizer = TweetTokenizer(strip_handles=True, reduce_len=True)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/tandemelephant/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

def token_cleaner(token_list):
    
    stemmer = SnowballStemmer('english')
    stop_words = set(stopwords.words('english'))
    regex = regex = re.compile(r'\w\w+')
    
    tokens = [x for x in token_list if x not in stop_words]
    return list(filter(regex.search, [stemmer.stem(x) for x in tokens]))

# %%
tokens = data.text.apply(tokenizer.tokenize).apply(token_cleaner)

# %%
all_words = [word for sublist in tokens.values for word in sublist ]

# %%
from wordcloud import WordCloud
word_cloud = WordCloud().generate(' '.join(all_words))

fig, ax = plt.subplots(figsize=(12,12))

ax.imshow(word_cloud, interpolation='bilinear', cmap='autumn')

plt.axis('off')
plt.savefig('../img/london_cloud.png', facecolor='black')
plt.show()
