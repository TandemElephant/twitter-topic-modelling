# %% [markdown]
# # Clean that twitter data!
#
# Use of the "Table of Contents" nbextension is highly recommended.

# %% [markdown]
# ### Basic imports, settings

# %%
import sys
sys.path.append('/home/tandemelephant/anaconda3/envs/graph-tool/lib/python3.7/site-packages')

import numpy as np
import pandas as pd
import re
import nltk
import os
import json
import matplotlib.pyplot as plt
from copy import deepcopy

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth',100)

# %% [markdown]
# ## Read data

# %%
dir_path = '../data/tweets_maga'
data_original = pd.DataFrame()

print('Loading tweets from', dir_path)
file_names = [file for file in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, file))]
for file_name in file_names:
    
    if not re.match(r'tweets_', file_name):
        continue
        
    file_path = dir_path + '/' + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        tweets = pd.read_json(file)
        data_original = pd.concat([data_original, tweets], ignore_index=True)
        
print('Successfully loaded {} tweets from {} files.'.format(len(data_original), len(file_names)))
# Out:
# Loading tweets from ../data/tweets_maga
# Successfully loaded 50000 tweets from 54 files.

# %%
data_original.text.str.len().mean()
# Out:
# 182.48442

# %%
tokenizer = TweetTokenizer(strip_handles=True, reduce_len=True)
tokens = data_original.text.apply(lambda text: tokenizer.tokenize(re.sub(r'[^\w]', ' ', 
                                                                  re.sub(r'http(\S)*', '', 
                                                                  re.sub(r'@\S*', '', 
                                                                  re.sub(r'#\S*', '', text))))))

# %%
tokens
# Out:
# 0        [realDonaldTrump, I, m, confused, Is, this, a, new, greatest, or, the, same, as, the, old, All, ...
# 1                      [realDonaldTrump, Hyundai, Kia, Aptiv, I, m, not, yet, tired, of, winning, Sir, MAGA]
# 2        [WA_Silenced_Maj, realDonaldTrump, You, are, the, true, patriots, If, Antifa, physically, assaul...
# 3        [It, is, amazing, to, watch, RudyGiuliani, throw, his, reputation, down, the, toilet, My, guess,...
# 4                     [w_terrence, realDonaldTrump, WHOOOHOOO, I, m, so, excited, for, you, MAGA, KAG, 2020]
# 5        [Trump, LIED, ABOUT, WIKILEAKS, in, MuellerReport, The, grand, jury, REDACTIONS, in, special, co...
# 6                      [Never, polled, and, don, t, know, anyone, that, has, MAGA, https, t, co, n1bzaxntWX]
# 7        [GettumGirl, Maga, needs, to, get, off, their, ass, and, put, their, foot, down, Dems, Antifa, s...
# 8                                                                    [realDonaldTrump, Beautiful, KAG, MAGA]
# 9        [RedOctober, Did, Q, mean, this, October, Maybe, JuanOSavin, is, onto, something, regarding, thi...
# 10                                     [realDonaldTrump, That, s, not, how, it, works, fatso, impeach, MAGA]
# 11       [Trump, Farmers, who, want, me, to, end, my, trade, war, are, dumb, people, MAGA, https, t, co, ...
# 12       [Duke, University, s, Student, Government, Rejects, Christian, Organization, Citing, LGBT, Polic...
# 13       [JjRedWave, 1, AngelStation, 007, Stonekeeper, 3, BlazeHunter, 14, Einsteinium, 2009, ProudArkgi...
# 14                                                       [Wtf, Wow, MAGA, QANON, https, t, co, iaLsBGDW, 4X]
# 15       [debshearer, 1, GOPChairwoman, realDonaldTrump, Ummm, Dumbo, I, dont, see, the, GOP, taking, a, ...
# 16       [Resist, FBR, MAGA, voteblue, It, wouldn, t, make, a, difference, who, they, faced, if, all, tho...
# 17                                                      [w_terrence, realDonaldTrump, Congratulations, MAGA]
# 18       [detj, 210, Ha37Rudy, lemonchronicle, no_silenced, We, will, never, agree, on, this, seeing, as,...
# 19       [DailyCaller, Sure, Flake, had, aspirations, of, becoming, POTUS, at, one, time, He, had, the, K...
# 20       [RealMattCouch, If, you, really, understand, what, has, happened, here, Trump, became, the, real...
# 21                                      [MAGA, is, the, only, way, to, stop, this, https, t, co, 8zFVPQuCWy]
# 22                             [JeffFlake, is, STILL, an, idiot, MAGA, MAGA, 2020, https, t, co, FE5hNjTpue]
# 23                                [realDonaldTrump, STRONG, FEARLESS, LEADER, TrumpTrain, MAGA, Trump, 2020]
# 24       [mitchellreports, SecPompeo, NBCNews, realDonaldTrump, Well, you, guys, have, done, nothing, but...
# 25       [realPowerTie, This, was, beautiful, Power, Tie, I, actually, pinned, it, to, my, timeline, that...
# 26       [kirstiealley, Imagine, a, day, when, a, person, accused, does, not, get, to, meet, their, accus...
# 27                            [Hey, MAGA, Your, leader, has, spoken, about, you, https, t, co, fRTeoJC, 0bi]
# 28                                 [Chief_Arrow, Ed_Nichols, 1, AND, the, WITCH, HUNT, will, be, over, MAGA]
# 29       [realDonaldTrump, WeThePeople, must, vote, RED, down, ballot, we, must, get, rid, of, the, Democ...
#                                                         ...
# 49970    [Some, will, never, wake, up, thebestcloser, SilentNoMore, MAGA, KAG, 2020, QAnon, WWG, 1WGA, Cl...
# 49971    [This, whole, thing, is, such, You, all, need, 2, get, over, yourselves, Grow, the, f, up, StopT...
# 49972    [Please, go, home, and, stop, talking, MAGA, KAG, Trump, 2020, https, t, co, fvMzTsPEcF, https, ...
# 49973    [Beyond, disgusting, and, disturbing, and, disgraceful, normandy, That, s, like, comparing, Trum...
# 49974    [MAGA, SecPompeo, markmeadows, JohnCornyn, mfa_russia, hey, lavrov, don, t, get, smug, every, MA...
# 49975    [MAGA, TrumpWarRoom, Foreign, Policy, in, January, 2017, 3, Ways, to, Get, Rid, of, President, T...
# 49976    [When, I, hear, the, name, robreiner, I, think, about, the, hick, in, the, Jerk, driving, the, p...
# 49977    [Yerman, 317, Damn, straight, He, s, awesome, If, only, the, Bitch, running, this, country, into...
# 49978                                                                      [thehill, Who, is, Rihanna, MAGA]
# 49979    [dianaarcher, _14, Bill_Maxwell, _, reddpdperbaby, Tell, you, what, I, didn, t, see, one, Kurd, ...
# 49980    [JHarden, 13, adidasHoops, Stick, to, losing, playoff, games, JHarden, 13, you, pro, Communist, ...
# 49981    [SpeakerPelosi, realDonaldTrump, Nancy, you, are, not, above, the, law, Where, s, the, vote, inc...
# 49982    [bennyjohnson, realDonaldTrump, How, could, she, understand, running, the, country, when, she, c...
# 49983    [Nucera, was, recorded, by, his, own, officers, as, he, went, on, racist, rants, against, nonwhi...
# 49984    [nytimes, MAGA, what, distinguishes, whining, from, typesful, of, vocalizationful, is, how, it, ...
# 49985    [Liberals, passed, anti, pipeline, Bill, C, 69, willfully, ignorant, of, economic, impact, Sheil...
# 49986    [IlhanMN, Go, away, Bye, bye, traitor, MAGA, AMERICAFIRST, BLEXIT, WALKAWAY, TRUMP, 2020, AMERIC...
# 49987    [The, expanded, parameters, of, the, Durham, probe, also, makes, clear, that, Rod, Rosenstein, a...
# 49988    [THIS, is, the, kind, of, know, nothing, who, advises, TRUMP, THIS, is, the, kind, of, informati...
# 49989    [SteveDelfin, SergioGor, realDonaldTrump, Such, a, lazy, simplistic, unthoughtful, bitter, comme...
# 49990    [No, Problem, Wethepeople, do, not, plan, to, keep, ANY, of, BHO, s, promises, DACA, is, between...
# 49991    [MAGA, Putting, our, allies, the, Kurds, at, risk, of, genocide, those, very, allies, who, lost,...
# 49992    [TeamTrump, MAGA, realDonaldTrump, Trump, 2020, America, GOP, RealTalkPundit, UpsetALiberal, MAG...
# 49993    [I, could, not, explain, it, any, better, MAGA, KAG, Trump, 2020, Check, out, Aubri, s, video, T...
# 49994    [No, immigration, deal, that, doesn, t, include, end, chain, migration, visa, lottery, huge, fin...
# 49995    [The, GOP, has, blood, on, their, hands, MAGA, supporters, have, blood, on, their, hands, https,...
# 49996    [DeepStateExpose, realDonaldTrump, Um, it, s, a, joke, Christian, Kurds, are, being, killed, bec...
# 49997    [Benghazi, MAGA, WWG, 1WGA, GreatAwakening, DarkToLight, TraitorsJustice, and, EQUAL, JusticeFor...
# 49998    [MarkRuffalo, To, get, back, at, Iran, for, the, humiliation, of, the, hostage, crisis, in, the,...
# 49999    [RicciGeri, rickahyatt, They, don, t, have, to, turn, it, Blue, They, just, have, to, put, in, V...
# Name: text, Length: 50000, dtype: object

# %%
tokens.str.len().max()
# Out:
# 72

# %% [markdown]
# ## Clean data

# %%
from nltk import edit_distance
from nltk.tokenize import TweetTokenizer
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/tandemelephant/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/tandemelephant/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
STOP_WORDS = set(stopwords.words('english'))
STEMMER = SnowballStemmer('english')
LEMMATIZER = WordNetLemmatizer()
EXCLUDE_TOKENS = set(['amp'])

def lemmatize_stem(word):
    return STEMMER.stem(LEMMATIZER.lemmatize(word, pos='v'))

def preprocess_text(text):
    
    # everything in lower case, strip
    text = text.lower().strip()
    
    # remove every #tag, @username, links
    text = re.sub(r'http(\S)*', '', re.sub(r'@\S*', '', re.sub(r'#\S*', '', text)))
    # replace every non alphanumeric character with whitespace
    text = re.sub(r'[^\w]', ' ', text)
    
    # tokenize
    tokenizer = TweetTokenizer(strip_handles=True, reduce_len=True)
    tokens = tokenizer.tokenize(text)
    
    
    # remove words with length < 3, or starting with non alphanumeric characters
    # remove stopwords
    
    pattern = re.compile('\w\w\w+')
    tokens = list(filter(pattern.match, [t for t in tokens if t not in STOP_WORDS]))
    
    # lemmatize and stem
    tokens = [lemmatize_stem(t) for t in tokens]
    
    #custom filters
    return [t for t in tokens if t not in EXCLUDE_TOKENS]

# %%
data = deepcopy(data_original)
# data = deepcopy(data_original[(original_text.str.lower().str.find('#brexit') > -1)])
data['tokens'] = data.text.apply(preprocess_text)
data[['text','tokens']]
# Out:
#                                                                                                       text  \
# 0      @realDonaldTrump I’m confused. Is this a new “greatest” or the same as the old? All of your scan...
# 1                          @realDonaldTrump @Hyundai @Kia @Aptiv I'm not yet tired of winning, Sir!  #MAGA
# 2      @WA_Silenced_Maj @realDonaldTrump You are the true patriots!  If Antifa physically assaults you ...
# 3      It is amazing to watch @RudyGiuliani throw his reputation down the toilet. My guess @realDonaldT...
# 4                   @w_terrence @realDonaldTrump WHOOOOOHOOOOO! I’m so excited for you! #MAGA #KAG2020♥️🇺🇸
# ...                                                                                                    ...
# 49995  The @GOP has blood on their hands.\n#MAGA supporters have blood on their hands. https://t.co/Kvm...
# 49996  @DeepStateExpose @realDonaldTrump Um... it’s a joke.\nChristian Kurds are being killed because o...
# 49997  #Benghazi #MAGA #WWG1WGA #GreatAwakening #DarkToLight #TraitorsJustice and EQUAL #JusticeForAll ...
# 49998  @MarkRuffalo To get back at Iran for the humiliation of the hostage crisis, in the waning days o...
# 49999  @RicciGeri @rickahyatt They don't have to turn it Blue.\nThey just have to put in Vote Machines ...
#
#                                                                                                  tokens
# 0                                       [confus, new, greatest, old, scandal, hard, follow, pussygrabb]
# 1                                                                                 [yet, tire, win, sir]
# 2                                          [true, patriot, antifa, physic, assault, way, legal, defend]
# 3                [amaz, watch, throw, reput, toilet, guess, someth, mayb, bumbl, old, fool, hard, tell]
# 4                                                                                    [whooohooo, excit]
# ...                                                                                                 ...
# 49995                                                               [blood, hand, support, blood, hand]
# 49996                                          [joke, christian, kurd, kill, trump, joke, impeach, con]
# 49997                                                                                     [equal, late]
# 49998  [get, back, iran, humili, hostag, crisi, wan, day, carter, administr, bush, fault, mark, realli]
# 49999                                           [turn, blue, put, vote, machin, own, soro, count, vote]
#
# [50000 rows x 2 columns]

# %% [markdown]
# ### (optional) Remove duplicates (by token)

# %%
# # remove duplicates
# no_duplicate_ids = data.text.str.replace(r'http(\S)*', ''
#                            ).str.replace(r'@\S*', ''
#                            ).str.replace(r'#\S*', ''
#                            ).drop_duplicates().index

# remove duplicates
no_duplicate_ids = data.tokens.str.join('').drop_duplicates().index

data = data.loc[no_duplicate_ids]
print(f'Dropped {len(data_original) - len(no_duplicate_ids)} duplicates.')
print(f'Data has {len(data)} rows remaining.')
# Out:
# Dropped 5225 duplicates.
# Data has 44775 rows remaining.

# %% [markdown]
# ## Save data

# %%
data.to_csv(dir_path + '/' + 'data_merged.csv')

# %% [markdown]
# ## Wordcloud

# %%
from wordcloud import WordCloud
all_words = [word for sublist in data.tokens.values for word in sublist ]
word_cloud = WordCloud(width = 600, height=600, background_color='white', colormap='Wistia').generate(' '.join(all_words))

fig, ax = plt.subplots(figsize=(16,16))

ax.imshow(word_cloud, interpolation='bilinear')

plt.axis('off')
plt.savefig('../img/maga_cloud.png', facecolor='white')
plt.show()
